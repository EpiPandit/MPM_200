# %% [markdown]
# <a href="https://colab.research.google.com/github/EpiPandit/MPM_200/blob/main/session%208/251119_psk_demo_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Demo notebook for MPM_200
#
#
# This is a dummy code to demonstrate
# 1. Integration of Google colab with Github
# 2. Integration of Github repository with Github

# %%
install.packages('tidyverse')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)

# %%
data = data.frame(a = factor(rep(1:3, each = 3), levels = 1:3, ordered = T), b = runif(9), c = sample(10:18))

data
# Out:
#   a b         c
# 1 1 0.4804421 12
# 2 1 0.7053010 16
# 3 1 0.2225065 10
# 4 2 0.1519229 18
# 5 2 0.5410122 11
# 6 2 0.7209162 13
# 7 3 0.7673857 15
# 8 3 0.1610103 17
# 9 3 0.6133626 14

# %%
ggplot(data, aes(x = c, y = b, color = a)) +
  geom_point(size = 5) +
  geom_line(aes(group = a)) +
  labs(x = "x", y = "f(x)", color = "Group") +
  theme_linedraw() +
  theme(axis.title = element_text(size = 16, face = "bold"),
                                axis.text = element_text(size = 14),
                                legend.text = element_text(size = 14),
                                legend.title = element_text(size = 16, face = "bold"),
                                legend.position = "bottom")
# Out:
# plot without title

# %%
summary(data)
# Out:
#  a           b                c
#  1:3   Min.   :0.1519   Min.   :10
#  2:3   1st Qu.:0.2225   1st Qu.:12
#  3:3   Median :0.5410   Median :14
#        Mean   :0.4849   Mean   :14
#        3rd Qu.:0.7053   3rd Qu.:16
#        Max.   :0.7674   Max.   :18
